# %% [markdown]
# # AE 771 | Homework \#5 | Rocket Propulsion | Ray Taghavi
# ### Code Written by Henry Hunt

# %% [markdown]
# Plot Figure 3.5 for k=1.2 and an epsilon of 50.
#
# Plot Figure 3.6 for k=1.2 and P1/P3=100.
#
# Complete Example 3.2 and recreate Figure 3.3 using the information from Example 3.2
#
# This is due before class on Wednesday 2/12.

# %%
#Python Initiation
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import sympy
from scipy.interpolate import make_interp_spline, BSpline
# %matplotlib inline

#Graph Formatting
fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 14
fig_size[1] = 10
plt.rcParams["figure.figsize"] = fig_size
Res=300 #Resoultion of the calulations

#Editing Font Size for Plot
font = {'size'   : 18}
matplotlib.rc('font', **font)

# %% [markdown]
# ## Part 1 | Plot of Figure 3.5 from Rocket Propulsion Elements
# Thrust coefficient CF as a function of pressure ratio, nozzle area ratio, and specific heat ratio for optimum expansion conditions (p2 = p3).
# ![image.png](attachment:image.png)

# %%
#Equations + Definitions
def CF_ideal(k,p2p1):
    CF=(((2*k**2)/(k-1))*(2/(k+1))**((k+1)/(k-1))*(1-(p2p1)**((k-1)/k)))**0.5
    return CF
def AreaRatio(k,p2p1):
    AR=((k+1)/2)**(1/(k-1))*(p2p1)**(1/k)*(((k+1)/(k-1))*(1-p2p1**((k-1)/k)))**0.5
    AR=AR**-1
    return AR
def FindEpsln(numbers,eps):   
    numbers = np.asarray(numbers) 
    i=(np.abs(numbers - eps)).argmin() 
    return numbers[i]       
h_color=['#990000','#FF0000','#FF3300','#FF6600','#FF9900'] #Hot Colors
c_color=['#311b92','#1a237e','#0d47a1','#01579b','#006064','#004d40','#1b5e20','#33691e','#827717'] #Cold Colors
b_color=['#0d47a1','#1565c0','#1976d2','#039be5','#03a9f4','#29b6f6','#4dd0e1','#80deea','#b2ebf2'] #Blues

#Plotting k Values
Kay=[1.1,1.2,1.25,1.3,1.4] #Range of Ratio of Specific Heats | Unitless
color=0 #Reseting Custom Color Code
for k in Kay:
        P1_P2=np.arange(10.0,10000.1,0.1)
        P2_P1=P1_P2**(-1)
        CF=CF_ideal(k,P2_P1)
        k_lab="k="+ str(k)
        plt_color=h_color[color]
        color=color+1
        plt.plot(p1p2,CF,color=(plt_color),label=(k_lab))

#Plotting Epsilon Values
Eps=[3,5,10,20,30,40,50,60,100] #Range of Epsilon Values | Unitless
color=0 #Reseting Custom Color Code
for x in Eps:
        ε=x
        CF_coords=[]
        P_coords=[]
        for k in Kay:
            AR=AreaRatio(k,P2_P1)
            AR=AR.tolist()
            CF_coords.append(CF_ideal(k,P2_P1[AR.index(FindEpsln(AR,ε))]))
        for k in Kay:
            AR=AreaRatio(k,P2_P1)
            AR=AR.tolist()
            P_coords.append(P1_P2[AR.index(FindEpsln(AR,ε))])
        ε_lab="ε="+str(ε)
        plt_color=b_color[color]
        color=color+1
        plt.plot(P_coords,CF_coords,color=(plt_color),label=ε_lab)

#Formatting the Graph
plt.legend(loc='upper left', borderaxespad=0.) #Showing the Graph Legend
plt.xlabel('$P_1/P_2$')                        #Setting the X label
plt.ylabel('$C_F$')                            #Setting the Y label
plt.legend(loc='best', borderaxespad=0.)       #Showing the Graph Legend
plt.xlim([10,10000])                           #Setting the range for the X-axis
plt.ylim([1.2,2.3])                            #Setting the range for the Y-axis
plt.xscale('log')                              #Setting the X scale to log
plt.title('Figure 3-5. Thrust Coefficient Relations for Optimum Expansion Conditions')
plt.show()

# %%
# Figure 3.5
# Inputs
k_val=[1.2]
ε=50
P1_P2=np.linspace(10,10000,1000)
P2_P1=1/P1_P2

#Primary Line Equation + Plot
for k in k_val: 
    CF=np.sqrt((((2*k**2)/(k-1))*(2/(k+1))**((k+1)/(k-1))*(1-(P2_P1)**((k-1)/k))))
    plt.plot(P1_P2,CF)
    
#Equations to be Updated Later
#ε=((k+1)/2)**(1/(k-1))*(P2_P1)**(1/k)*((k+1)/(k-1)*(1-P2_P1**((k-1)/k)))**(1/2)
CF_=k**3+P2_P1*ε

#Plotting Parameters
plt.ylabel('$C_F$ (Unitless)')
plt.xlabel('$P_1/P_2$ (Unitless)')
plt.plot(P1_P2,CF_)
plt.xscale('log')
plt.xlim(10,10000)
plt.ylim(1.2,2.3)
plt.legend(['k=1.2','ε=50'])
plt.show()

# %% [markdown]
# ## Plot of Figure 3.6 from Rocket Propulsion Elements

# %%
k=[1.2]
P1_P3=100

#Primary Line Equation + Plot
for k in k_val: 
    CF=np.sqrt((((2*k**2)/(k-1))*(2/(k+1))**((k+1)/(k-1))*(1-(P2_P1)**((k-1)/k))))
    plt.plot(P1_P2,CF)
    
#Equations to be Updated Later
#ε=((k+1)/2)**(1/(k-1))*(P2_P1)**(1/k)*((k+1)/(k-1)*(1-P2_P1**((k-1)/k)))**(1/2)
CF_=k**3+P2_P1*ε

#Plotting Parameters
plt.ylabel('$C_F$ (Unitless)')
plt.xlabel('$P_1/P_2$ (Unitless)')
plt.plot(P1_P2,CF_)
plt.xscale('log')
plt.xlim(10,10000)
plt.ylim(1.2,2.3)
plt.legend(['k=1.2','ε=50'])
plt.show()

# %% [markdown]
# ## Example 3.2 and Recreation of Figure 3.3 from Rocket Propulsion Elements
